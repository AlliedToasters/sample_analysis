# %%
from loyalty_program import *

# %%
df = load_data()
bal = get_class_balance(df, verbose=True)
# Out:
#    purch_amt  gender card_on_file   age  days_since_last_purch  loyalty
# 0      19.58    male           no  31.0                   35.0    False
# 1      65.16    male          yes  23.0                   61.0    False
# 2      40.60  female           no  36.0                   49.0    False
# 3      38.01    male          yes  47.0                   57.0    False
# 4      22.32  female          yes   5.0                   39.0    False
#
# 16.67% of customers are loyalty program members.
#
# The ratio of loyalty customers to non-loyalty customers is:  0.2

# %%
visualize_continuous_variables(df)
# Out:
# the mean purch_amt for loyalty members is:  53.93
# the mean purch_amt for non loyalty members is:  42.06
# the mean age for loyalty members is:  29.89
# the mean age for non loyalty members is:  24.99
# the mean days_since_last_purch for loyalty members is:  39.82
# the mean days_since_last_purch for non loyalty members is:  59.96

# %%
visualize_variable_interactions(df)
# Out:
# /home/alliedtoasters/miniconda3/envs/dev1/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6448: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
gender_tab, card_tab = inspect_binary_variables(df)
print('loyalty membership and gender:\n', gender_tab, '\n')
print('loyalty membership and card-on-file status:\n', card_tab, '\n')
# Out:
# loyalty membership and gender:
#  gender   female   male     All
# loyalty
# False     49912  50088  100000
# True       9907  10093   20000
# All       59819  60181  120000
#
# loyalty membership and card-on-file status:
#  card_on_file     no    yes     All
# loyalty
# False         49916  50084  100000
# True           9997  10003   20000
# All           59913  60087  120000

# %%
pred_tab = model_binary_variables(df)
print('binary variable prediction results:\n', pred_tab)
# Out:
# binary variable prediction results:
#  col_0     True
# loyalty
# False    50029
# True      9971

# %%
model, report, accuracy, tab = model_all_variables(df)
print('\nall variable prediction results:\n\n', report)
print('\nclassification accuracy:\n\n', round(accuracy, 3))
print('\nclassification table:\n\n', tab)
# Out:
# all variable prediction results:
#
#               precision    recall  f1-score   support
#
#       False       0.89      0.94      0.91     50029
#        True       0.59      0.40      0.48      9971
#
# avg / total       0.84      0.85      0.84     60000
#
#
# classification accuracy:
#
#  0.854
#
# classification table:
#
#  col_0    False  True
# loyalty
# False    47241   2788
# True      5990   3981

# %%
visualize_feature_importance(model)
